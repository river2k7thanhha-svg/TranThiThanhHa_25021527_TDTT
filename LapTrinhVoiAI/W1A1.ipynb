# %%
# W1A1:
# Dòng 1: Gán giá trị 7 cho biến 'a'.
a = 7
# Dòng 2: Gán giá trị 5 cho biến 'b'.
b = 5
# Dòng 3: Thực hiện phép trừ, lấy giá trị của 'a' trừ đi giá trị của 'b'
# và gán kết quả cho biến 'c'.
c = a - b
# Dòng 4: In ra giá trị của biến 'c'.
print(c)
# Giải thích kết quả:
# 1. a = 7
# 2. b = 5
# 3. c = 7 - 5 = 2
# Kết quả in ra là 2.
# Out:
# 2

# %%
#W1A6:
##=== Al Prediction System ===
1.Sentiment analysis
2.Weather forecast
3.Exit 
Please choose an option:

#Giải thích:

Chức năng: Chương trình này là một hệ thống menu đơn giản (Simple Menu) được thiết kế để người dùng tương tác, mô phỏng một "Hệ thống Dự đoán AI".

Hoạt động:
   Nó in ra tiêu đề === Al Prediction System === để giới thiệu hệ thống.
   Nó hiển thị ba tùy chọn có thể chọn:
1) Sentiment analysis (Phân tích cảm xúc)
2) Weather forecast (Dự báo thời tiết)
3) Exit (Thoát)
   Sau cùng, nó in ra lời nhắc Please choose an option: để yêu cầu người dùng nhập số tương ứng với tùy chọn họ muốn.
   Kết quả (Output): Đây là kết quả đầu ra in ra màn hình. 
   === Al Prediction System ===
1.Sentiment analysis
2.Weather forecast
3.Exit 
Please choose an option:

Lý do: Chương trình chỉ bao gồm các lệnh in (print) liên tiếp nhau để hiển thị một giao diện người dùng dựa trên văn bản. Nó không có chức năng xử lý đầu vào hoặc thực hiện logic.

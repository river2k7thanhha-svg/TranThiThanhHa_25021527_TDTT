# %%
#W1A9: 
#Giải thích đoạn code sau in ra mấy dòng, nội dung là gì.
for x in ["cat", "dog", "fish"]:
    print("Dự đoán con vật:", x)
#Giải thích:
1.  Công việc thực hiện: Đoạn code duyệt qua từng phần tử trong danh sách và in ra chúng.
2.  Số dòng in ra: 3 dòng.
3.  Nội dung in ra:
    Dự đoán con vật: cat
    Dự đoán con vật: dog
    Dự đoán con vật: fish
4.  Lý do: Vòng lặp chạy số lần bằng số lượng phần tử trong danh sách (3 phần tử).

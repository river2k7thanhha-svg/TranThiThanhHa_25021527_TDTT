# %%
#W1A10: 
Sử dụng AI tìm lỗi cú pháp để sửa đoạn chương trình sau cho chạy đúng.
# Simple menu
print ""=== Al Prediction System ===""
print(""1) Sentiment analysis""
print(""2) Weather forecast""))
print('3) Exit'
print(""Please choose an option:"")

#Giải thích:
Các lỗi cú pháp đã được sửa:
1.  Dấu ngoặc đơn của hàm `print`:** Lệnh `print` ở dòng 2 thiếu dấu ngoặc đơn `()`. Đã sửa thành `print("...")`.
2.  Lồng lệnh và thừa dấu ngoặc:** Các lệnh `print` ở dòng 3 và 4 bị lồng vào nhau và thừa dấu đóng ngoặc `))`. Đã tách thành các lệnh độc lập.
3.  Thiếu dấu đóng ngoặc:** Lệnh `print('3) Exit'` thiếu dấu đóng ngoặc đơn. Đã sửa thành `print('3) Exit')`.
